# %%
import requests
r = requests.get("https://canvas.instructure.com/api/v1/courses?access_token=1030~eKh6WrTYtmUJyeaemXTPR6DPNFJ6vyY8LUGRvfW7Q8NEa3ZDtJ7vK4aCKvmGc6VX")
r.json()
# Out:
# [{'id': 10300000000067763,
#   'name': '2023F AAI 695-A',
#   'account_id': 10300000000000083,
#   'uuid': 'SX1LJJt0pZrRxRPgm1cHEiIzzIpI7Di8jiH9Ufce',
#   'start_at': '2023-09-01T00:00:00Z',
#   'grading_standard_id': None,
#   'is_public': False,
#   'created_at': '2023-03-07T19:00:28Z',
#   'course_code': 'Applied Machine Learning',
#   'default_view': 'wiki',
#   'root_account_id': 10300000000000001,
#   'enrollment_term_id': 10300000000000478,
#   'license': 'private',
#   'grade_passback_setting': None,
#   'end_at': '2023-12-22T00:00:00Z',
#   'public_syllabus': False,
#   'public_syllabus_to_auth': False,
#   'storage_quota_mb': 15728,
#   'is_public_to_auth_users': False,
#   'homeroom_course': False,
#   'course_color': None,
#   'friendly_name': None,
#   'apply_assignment_group_weights': False,
#   'calendar': {'ics': 'https://canvas.instructure.com/feeds/calendars/course_SX1LJJt0pZrRxRPgm1cHEiIzzIpI7Di8jiH9Ufce.ics'},
#   'time_zone': 'America/New_York',
#   'blueprint': False,
#   'template': False,
#   'enrollments': [{'type': 'student',
#     'role': 'StudentEnrollment',
#     'role_id': 10300000000000006,
#     'user_id': 10300000000076506,
#     'enrollment_state': 'active',
#     'limit_privileges_to_course_section': False}],
#   'hide_final_grades': False,
#   'workflow_state': 'available',
#   'restrict_enrollments_to_course_dates': False},
#  {'id': 10300000000069189,
#   'name': '2023F MA 540-A',
#   'account_id': 10300000000000102,
#   'uuid': '2Ya1RLhDaPRqpU3uREpAcAQjjeFaHQQOleDV3ws2',
#   'start_at': '2023-09-01T00:00:00Z',
#   'grading_standard_id': None,
#   'is_public': False,
#   'created_at': '2023-03-27T20:32:05Z',
#   'course_code': 'Introduction to Probability Theory',
#   'default_view': 'wiki',
#   'root_account_id': 10300000000000001,
#   'enrollment_term_id': 10300000000000478,
#   'license': 'private',
#   'grade_passback_setting': None,
#   'end_at': '2023-12-22T00:00:00Z',
#   'public_syllabus': False,
#   'public_syllabus_to_auth': False,
#   'storage_quota_mb': 15728,
#   'is_public_to_auth_users': False,
#   'homeroom_course': False,
#   'course_color': None,
#   'friendly_name': None,
#   'apply_assignment_group_weights': False,
#   'calendar': {'ics': 'https://canvas.instructure.com/feeds/calendars/course_2Ya1RLhDaPRqpU3uREpAcAQjjeFaHQQOleDV3ws2.ics'},
#   'time_zone': 'America/New_York',
#   'blueprint': False,
#   'template': False,
#   'enrollments': [{'type': 'student',
#     'role': 'StudentEnrollment',
#     'role_id': 10300000000000006,
#     'user_id': 10300000000076506,
#     'enrollment_state': 'active',
#     'limit_privileges_to_course_section': False}],
#   'hide_final_grades': False,
#   'workflow_state': 'available',
#   'restrict_enrollments_to_course_dates': False},
#  {'id': 10300000000069212,
#   'name': '2023F MA 574-A',
#   'account_id': 10300000000000102,
#   'uuid': 'H0HBEwNQb4q5cP5WZaBqXEtwXUf4j39XMiYNuKSx',
#   'start_at': '2023-09-01T00:00:00Z',
#   'grading_standard_id': None,
#   'is_public': False,
#   'created_at': '2023-03-27T20:32:06Z',
#   'course_code': 'Foundational Mathematics for Data Science',
#   'default_view': 'wiki',
#   'root_account_id': 10300000000000001,
#   'enrollment_term_id': 10300000000000478,
#   'license': 'private',
#   'grade_passback_setting': None,
#   'end_at': '2023-12-22T00:00:00Z',
#   'public_syllabus': False,
#   'public_syllabus_to_auth': False,
#   'storage_quota_mb': 15728,
#   'is_public_to_auth_users': False,
#   'homeroom_course': False,
#   'course_color': None,
#   'friendly_name': None,
#   'apply_assignment_group_weights': True,
#   'calendar': {'ics': 'https://canvas.instructure.com/feeds/calendars/course_H0HBEwNQb4q5cP5WZaBqXEtwXUf4j39XMiYNuKSx.ics'},
#   'time_zone': 'America/New_York',
#   'blueprint': False,
#   'template': False,
#   'enrollments': [{'type': 'student',
#     'role': 'StudentEnrollment',
#     'role_id': 10300000000000006,
#     'user_id': 10300000000076506,
#     'enrollment_state': 'active',
#     'limit_privileges_to_course_section': False}],
#   'hide_final_grades': False,
#   'workflow_state': 'available',
#   'restrict_enrollments_to_course_dates': False},
#  {'id': 10300000000073698,
#   'name': '2024F CS 513-B',
#   'account_id': 10300000000000079,
#   'uuid': 'cXPbLa11YB62Swam5HiNNY4bNvEg74DpxkK8n7M5',
#   'start_at': '2024-09-03T00:00:00Z',
#   'grading_standard_id': None,
#   'is_public': False,
#   'created_at': '2024-03-05T00:00:34Z',
#   'course_code': 'Knowledge Discovery and Data Mining',
#   'default_view': 'wiki',
#   'root_account_id': 10300000000000001,
#   'enrollment_term_id': 10300000000000490,
#   'license': 'private',
#   'grade_passback_setting': None,
#   'end_at': '2024-12-22T00:00:00Z',
#   'public_syllabus': False,
#   'public_syllabus_to_auth': False,
#   'storage_quota_mb': 15728,
#   'is_public_to_auth_users': False,
#   'homeroom_course': False,
#   'course_color': None,
#   'friendly_name': None,
#   'apply_assignment_group_weights': False,
#   'calendar': {'ics': 'https://canvas.instructure.com/feeds/calendars/course_cXPbLa11YB62Swam5HiNNY4bNvEg74DpxkK8n7M5.ics'},
#   'time_zone': 'America/New_York',
#   'blueprint': False,
#   'template': False,
#   'enrollments': [{'type': 'student',
#     'role': 'StudentEnrollment',
#     'role_id': 10300000000000006,
#     'user_id': 10300000000076506,
#     'enrollment_state': 'active',
#     'limit_privileges_to_course_section': False}],
#   'hide_final_grades': False,
#   'workflow_state': 'available',
#   'restrict_enrollments_to_course_dates': False},
#  {'id': 10300000000073737,
#   'name': '2024F CS 583-B',
#   'account_id': 10300000000000079,
#   'uuid': 'kxuv2UZRDCHUiIIrFrzcH4nkr95LPSAMsQgyv7FE',
#   'start_at': '2024-09-03T00:00:00Z',
#   'grading_standard_id': None,
#   'is_public': False,
#   'created_at': '2024-03-05T00:00:38Z',
#   'course_code': 'Deep Learning',
#   'default_view': 'wiki',
#   'root_account_id': 10300000000000001,
#   'enrollment_term_id': 10300000000000490,
#   'license': 'private',
#   'grade_passback_setting': None,
#   'end_at': '2024-12-22T00:00:00Z',
#   'public_syllabus': False,
#   'public_syllabus_to_auth': False,
#   'storage_quota_mb': 15728,
#   'is_public_to_auth_users': False,
#   'homeroom_course': False,
#   'course_color': None,
#   'friendly_name': None,
#   'apply_assignment_group_weights': False,
#   'calendar': {'ics': 'https://canvas.instructure.com/feeds/calendars/course_kxuv2UZRDCHUiIIrFrzcH4nkr95LPSAMsQgyv7FE.ics'},
#   'time_zone': 'America/New_York',
#   'blueprint': False,
#   'template': False,
#   'enrollments': [{'type': 'student',
#     'role': 'StudentEnrollment',
#     'role_id': 10300000000000006,
#     'user_id': 10300000000076506,
#     'enrollment_state': 'active',
#     'limit_privileges_to_course_section': False}],
#   'hide_final_grades': False,
#   'workflow_state': 'available',
#   'restrict_enrollments_to_course_dates': False},
#  {'id': 10300000000073287,
#   'name': '2024F EMT 678-A',
#   'account_id': 10300000000000105,
#   'uuid': 'kTyqmVH13qaioZYPd2BcFvB3u3KwzQgRqxQTRqKY',
#   'start_at': '2024-09-03T00:00:00Z',
#   'grading_standard_id': 10300000000001936,
#   'is_public': False,
#   'created_at': '2024-03-04T22:45:25Z',
#   'course_code': 'Big Data Technologies',
#   'default_view': 'wiki',
#   'root_account_id': 10300000000000001,
#   'enrollment_term_id': 10300000000000490,
#   'license': 'private',
#   'grade_passback_setting': None,
#   'end_at': '2024-12-30T05:00:00Z',
#   'public_syllabus': False,
#   'public_syllabus_to_auth': False,
#   'storage_quota_mb': 15728,
#   'is_public_to_auth_users': False,
#   'homeroom_course': False,
#   'course_color': None,
#   'friendly_name': None,
#   'apply_assignment_group_weights': False,
#   'calendar': {'ics': 'https://canvas.instructure.com/feeds/calendars/course_kTyqmVH13qaioZYPd2BcFvB3u3KwzQgRqxQTRqKY.ics'},
#   'time_zone': 'America/New_York',
#   'blueprint': False,
#   'template': False,
#   'enrollments': [{'type': 'student',
#     'role': 'StudentEnrollment',
#     'role_id': 10300000000000006,
#     'user_id': 10300000000076506,
#     'enrollment_state': 'active',
#     'limit_privileges_to_course_section': False}],
#   'hide_final_grades': False,
#   'workflow_state': 'available',
#   'restrict_enrollments_to_course_dates': True},
#  {'id': 10300000000071773,
#   'name': '2024S CS 584-A',
#   'account_id': 10300000000000079,
#   'uuid': 'HB3tQViWo47rxaRbxu0P5hanUlTQHV0UvQNZlbO0',
#   'start_at': '2024-01-17T00:00:00Z',
#   'grading_standard_id': None,
#   'is_public': False,
#   'created_at': '2023-10-11T22:00:42Z',
#   'course_code': 'Natural Language Processing',
#   'default_view': 'wiki',
#   'root_account_id': 10300000000000001,
#   'enrollment_term_id': 10300000000000482,
#   'license': 'private',
#   'grade_passback_setting': None,
#   'end_at': '2024-05-14T00:00:00Z',
#   'public_syllabus': False,
#   'public_syllabus_to_auth': False,
#   'storage_quota_mb': 15728,
#   'is_public_to_auth_users': False,
#   'homeroom_course': False,
#   'course_color': None,
#   'friendly_name': None,
#   'apply_assignment_group_weights': False,
#   'calendar': {'ics': 'https://canvas.instructure.com/feeds/calendars/course_HB3tQViWo47rxaRbxu0P5hanUlTQHV0UvQNZlbO0.ics'},
#   'time_zone': 'America/New_York',
#   'blueprint': False,
#   'template': False,
#   'enrollments': [{'type': 'student',
#     'role': 'StudentEnrollment',
#     'role_id': 10300000000000006,
#     'user_id': 10300000000076506,
#     'enrollment_state': 'active',
#     'limit_privileges_to_course_section': False}],
#   'hide_final_grades': False,
#   'workflow_state': 'available',
#   'restrict_enrollments_to_course_dates': False},
#  {'id': 10300000000072559,
#   'name': '2024S FE 535-WS',
#   'account_id': 10300000000000105,
#   'uuid': '48yzlmWWwtpKwRdvMnYbjCZI5TgNEKlz53CIGgDE',
#   'start_at': '2024-01-17T00:00:00Z',
#   'grading_standard_id': 10300000000001936,
#   'is_public': False,
#   'created_at': '2023-11-15T16:15:33Z',
#   'course_code': 'Introduction to Financial Risk Management',
#   'default_view': 'wiki',
#   'root_account_id': 10300000000000001,
#   'enrollment_term_id': 10300000000000482,
#   'license': 'private',
#   'grade_passback_setting': None,
#   'end_at': '2024-05-14T00:00:00Z',
#   'public_syllabus': False,
#   'public_syllabus_to_auth': False,
#   'storage_quota_mb': 15728,
#   'is_public_to_auth_users': False,
#   'homeroom_course': False,
#   'course_color': None,
#   'friendly_name': None,
#   'apply_assignment_group_weights': True,
#   'calendar': {'ics': 'https://canvas.instructure.com/feeds/calendars/course_48yzlmWWwtpKwRdvMnYbjCZI5TgNEKlz53CIGgDE.ics'},
#   'time_zone': 'America/New_York',
#   'blueprint': False,
#   'template': False,
#   'enrollments': [{'type': 'student',
#     'role': 'StudentEnrollment',
#     'role_id': 10300000000000006,
#     'user_id': 10300000000076506,
#     'enrollment_state': 'active',
#     'limit_privileges_to_course_section': False}],
#   'hide_final_grades': False,
#   'workflow_state': 'available',
#   'restrict_enrollments_to_course_dates': True},
#  {'id': 10300000000071068,
#   'name': '2024S MA 541-A',
#   'account_id': 10300000000000102,
#   'uuid': 'EukBXpoQwbhYJetjpVwk2NjmYYwJsd0Hu8CBmCGw',
#   'start_at': None,
#   'grading_standard_id': None,
#   'is_public': False,
#   'created_at': '2023-10-11T21:30:31Z',
#   'course_code': 'Statistical Methods',
#   'default_view': 'wiki',
#   'root_account_id': 10300000000000001,
#   'enrollment_term_id': 10300000000000482,
#   'license': 'private',
#   'grade_passback_setting': None,
#   'end_at': None,
#   'public_syllabus': False,
#   'public_syllabus_to_auth': False,
#   'storage_quota_mb': 15728,
#   'is_public_to_auth_users': False,
#   'homeroom_course': False,
#   'course_color': None,
#   'friendly_name': None,
#   'apply_assignment_group_weights': True,
#   'calendar': {'ics': 'https://canvas.instructure.com/feeds/calendars/course_EukBXpoQwbhYJetjpVwk2NjmYYwJsd0Hu8CBmCGw.ics'},
#   'time_zone': 'America/New_York',
#   'blueprint': False,
#   'template': False,
#   'enrollments': [{'type': 'student',
#     'role': 'StudentEnrollment',
#     'role_id': 10300000000000006,
#     'user_id': 10300000000076506,
#     'enrollment_state': 'active',
#     'limit_privileges_to_course_section': False}],
#   'hide_final_grades': False,
#   'workflow_state': 'available',
#   'restrict_enrollments_to_course_dates': False},
#  {'id': 10300000000071085,
#   'name': '2024S MA 576-A',
#   'account_id': 10300000000000102,
#   'uuid': 'vfFhVxzkxiov4AX63Lqa9N84ClS2qIAfRpC1pP1I',
#   'start_at': None,
#   'grading_standard_id': None,
#   'is_public': False,
#   'created_at': '2023-10-11T21:30:32Z',
#   'course_code': 'Optimization for Data Science',
#   'default_view': 'wiki',
#   'root_account_id': 10300000000000001,
#   'enrollment_term_id': 10300000000000482,
#   'license': 'private',
#   'grade_passback_setting': None,
#   'end_at': None,
#   'public_syllabus': False,
#   'public_syllabus_to_auth': False,
#   'storage_quota_mb': 15728,
#   'is_public_to_auth_users': False,
#   'homeroom_course': False,
#   'course_color': None,
#   'friendly_name': None,
#   'apply_assignment_group_weights': True,
#   'calendar': {'ics': 'https://canvas.instructure.com/feeds/calendars/course_vfFhVxzkxiov4AX63Lqa9N84ClS2qIAfRpC1pP1I.ics'},
#   'time_zone': 'America/New_York',
#   'blueprint': False,
#   'template': False,
#   'enrollments': [{'type': 'student',
#     'role': 'StudentEnrollment',
#     'role_id': 10300000000000006,
#     'user_id': 10300000000076506,
#     'enrollment_state': 'active',
#     'limit_privileges_to_course_section': False}],
#   'hide_final_grades': False,
#   'workflow_state': 'available',
#   'restrict_enrollments_to_course_dates': False}]

# %%
import requests

# Define the Canvas API URL
canvas_instance = "sit.instructure.com"
account_id = "1"  # Replace with your account ID
url = f"https://{canvas_instance}/api/v1/accounts/{account_id}/account_notifications"

# Define the headers with the access token
headers = {
    "Authorization": "Bearer 1030~eKh6WrTYtmUJyeaemXTPR6DPNFJ6vyY8LUGRvfW7Q8NEa3ZDtJ7vK4aCKvmGc6VX"
}

# Make the GET request
response = requests.get(url, headers=headers)

# Print the response
if response.status_code == 200:
    print("Account Notifications:", response.json())
else:
    print(f"Failed to fetch notifications. Status Code: {response.status_code}")
    print("Response:", response.text)
# Out:
# Account Notifications: []

# %%
import requests

# Define the Canvas API URL
canvas_instance = "sit.instructure.com"  # Replace with your Canvas domain
course_id = "73287"  # Replace with your course ID
url = f"https://{canvas_instance}/api/v1/announcements"

# Define query parameters
params = {
    "context_codes[]": f"course_{course_id}",
    "start_date": "2024-12-01T00:00:00Z",  # Replace with your desired start date
    "end_date": "2024-12-31T23:59:59Z",    # Replace with your desired end date
    "active_only": "true"
}

# Define headers with the access token
headers = {
    "Authorization": "Bearer 1030~eKh6WrTYtmUJyeaemXTPR6DPNFJ6vyY8LUGRvfW7Q8NEa3ZDtJ7vK4aCKvmGc6VX"
}

# Make the GET request
response = requests.get(url, headers=headers, params=params)

# Print the response
if response.status_code == 200:
    print("Announcements:", response.json())
else:
    print(f"Failed to fetch announcements. Status Code: {response.status_code}")
    print("Response:", response.text)
# Out:
# Announcements: [{'id': 506636, 'title': 'Course Evaluation/Survey Open', 'last_reply_at': '2024-12-03T12:16:05Z', 'created_at': '2024-12-03T12:16:05Z', 'delayed_post_at': None, 'posted_at': '2024-12-03T12:16:05Z', 'assignment_id': None, 'root_topic_id': None, 'position': 33, 'podcast_has_student_posts': False, 'discussion_type': 'threaded', 'lock_at': None, 'allow_rating': True, 'only_graders_can_rate': False, 'sort_by_rating': False, 'is_section_specific': True, 'anonymous_state': None, 'summary_enabled': False, 'user_name': 'Venu Guntupalli', 'discussion_subentry_count': 0, 'permissions': {'attach': False, 'update': False, 'reply': True, 'delete': False, 'manage_assign_to': False}, 'require_initial_post': None, 'user_can_see_posts': True, 'podcast_url': None, 'read_state': 'unread', 'unread_count': 0, 'subscribed': False, 'attachments': [], 'published': True, 'can_unpublish': False, 'locked': False, 'can_lock': True, 'comments_disabled': False, 'author': {'id': 14234, 'anonymous_id': 'aze', 'display_name': 'Venu Guntupalli', 'avatar_image_url': 'https://sit.instructure.com/images/messages/avatar-50.png', 'html_url': 'https://sit.instructure.com/courses/73287/users/14234', 'pronouns': None}, 'html_url': 'https://sit.instructure.com/courses/73287/discussion_topics/506636', 'url': 'https://sit.instructure.com/courses/73287/discussion_topics/506636', 'pinned': False, 'group_category_id': None, 'can_group': False, 'topic_children': [], 'group_topic_children': [], 'context_code': 'course_73287', 'ungraded_discussion_overrides': None, 'locked_for_user': False, 'message': '<p><span style="font-family: inherit; font-size: 1rem;">Hello, Class,</span></p>\n<div class="userMessage">\n<p>I hope everyone had a nice, productive break (as short as it feels now). I believe the course evaluations/surveys for this semester are open, I strongly encourage everyone to complete them. Not just for this class, but all your classes. You heard me say this multiple times - these surveys are very helpful for the department and the school to improve student outcomes. As a member of the Advisory Board at Stevens, I can tell you from first-hand account that these evaluations do make a difference. Please provide as much detail as you can in your feedback. I encourage you to do it for all your classes, it does make a difference. Thank you.</p>\n<p>Best,<br>Venu&nbsp;</p>\n</div>', 'subscription_hold': 'topic_is_announcement', 'todo_date': None, 'user_pronouns': 'He/Him', 'is_announcement': True}]

# %%
import requests

# Define the Canvas API URL
canvas_instance = "sit.instructure.com"  # Replace with your Canvas domain
url = f"https://{canvas_instance}/api/v1/conversations"

# Define query parameters
params = {
    "scope": "unread",  # Options: unread, starred, archived, sent (remove this for all messages)
}


# Define headers with the access token
headers = {
    "Authorization": "Bearer 1030~eKh6WrTYtmUJyeaemXTPR6DPNFJ6vyY8LUGRvfW7Q8NEa3ZDtJ7vK4aCKvmGc6VX"
}

# Make the GET request
response = requests.get(url, headers=headers, params=params)
response =response.json()
messages = {"subject":[],"message":[],"sender_name":[],"last_message_at":[]}
num_messages = len(response)
for res in response:
    subject = res["subject"]
    message = res["last_message"]
    sender_name = res["participants"][0]["name"]
    last_message_at = res["last_message_at"]
    messages["subject"].append(subject)
    messages["message"].append(message)
    messages["sender_name"].append(sender_name)
    messages["last_message_at"].append(last_message_at)
print(messages,num_messages)
# Out:
# {'subject': ['hii'], 'message': ['hey, how is your project "SKY AI" going on?'], 'sender_name': ['Komal Chandrakant Kadam'], 'last_message_at': ['2024-12-06T04:38:50Z']} 1

# %%
response
# Out:
# [{'id': 1712702,
#   'subject': 'hii',
#   'workflow_state': 'unread',
#   'last_message': 'hey, how is your project "SKY AI" going on?',
#   'last_message_at': '2024-12-06T04:38:50Z',
#   'last_authored_message': None,
#   'last_authored_message_at': None,
#   'message_count': 1,
#   'subscribed': True,
#   'private': False,
#   'starred': False,
#   'properties': [],
#   'audience': [76496],
#   'audience_contexts': {'courses': {'73287': ['StudentEnrollment']},
#    'groups': {}},
#   'avatar_url': 'https://sit.instructure.com/images/thumbnails/13020174/CTBuB9QjPJc2KaBDvHfgPS5v4YSASFGeuPt4tnjs',
#   'participants': [{'id': 76496,
#     'name': 'Komal Chandrakant Kadam',
#     'full_name': 'Komal Chandrakant Kadam',
#     'pronouns': None},
#    {'id': 76506,
#     'name': 'Akshay Kamlakar Parate',
#     'full_name': 'Akshay Kamlakar Parate',
#     'pronouns': 'He/Him'}],
#   'visible': True,
#   'context_code': 'course_73287',
#   'context_name': '2024F EMT 678-A'}]
